# %% [markdown]
# # T2.L2 — Practice notebook
#
# Виконайте завдання самостійно. Комірки `TODO` навмисно неповні.

# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib.pyplot as plt

LESSON = Path.cwd()
if LESSON.name == "notebooks":
    LESSON = LESSON.parent
SRC = LESSON / "src"
sys.path.insert(0, str(SRC))

from model import (
    validate_problem, solve_transport_pulp, solve_transport_scipy,
    check_solution, total_cost, long_plan
)

# %% [markdown]
# ## 1. Завантажте дані

# %%
# TODO: завантажте costs.csv, supply.csv, demand.csv
# costs = ...
# supply = ...
# demand = ...

# %% [markdown]
# ## 2. Перевірте баланс

# %%
# TODO:
# print(supply.sum(), demand.sum())
# validate_problem(costs, supply, demand)

# %% [markdown]
# ## 3. Запишіть модель словами та формулами
#
# TODO:
# - що означає `x_ij`;
# - цільова функція;
# - обмеження джерел;
# - обмеження потреб;
# - щонайменше 3 припущення.

# %% [markdown]
# ## 4. Знайдіть baseline optimum

# %%
# TODO:
# baseline = solve_transport_pulp(costs, supply, demand)
# display(baseline.plan)
# print(baseline.total_cost)

# %% [markdown]
# Контрольне значення для самоперевірки: **515**.

# %% [markdown]
# ## 5. Verification

# %%
# TODO:
# check_solution(...)
# total_cost(...)
# scipy_result = solve_transport_scipy(...)
# порівняйте два оптимальні значення

# %% [markdown]
# Поясніть: чому `solver status = Optimal` ще не означає, що модель адекватна реальній системі?

# %% [markdown]
# ## 6. Обов'язковий сценарій — закрити S2 → D3

# %%
# TODO:
# closed = solve_transport_pulp(..., forbidden_routes=[("S2","D3")])
# display(closed.plan)
# print(closed.total_cost)

# %% [markdown]
# Контрольне значення: **570**.

# %% [markdown]
# ## 7. Два власні сценарії

# %%
# TODO Scenario 2

# TODO Scenario 3

# %% [markdown]
# Для кожного сценарію зафіксуйте:
# - що змінилося;
# - новий план;
# - нову вартість;
# - абсолютну/відносну зміну;
# - пояснення.

# %% [markdown]
# ## 8. Візуалізація

# %%
# TODO: heatmap оптимального плану

# TODO: bar chart порівняння сценаріїв

# %% [markdown]
# ## 9. Висновок
#
# Сформулюйте 5–7 речень: що модель показала, які маршрути/параметри є критичними, чого з результату стверджувати не можна.

# %% [markdown]
# ## 10. Research transfer
#
# Визначте для власного дослідження:
# `S_i`, `D_j`, `x_ij`, `c_ij`, дані, обмеження та одну причину, чому базова лінійна модель може бути недостатньою.
