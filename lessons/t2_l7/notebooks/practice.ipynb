# %% [markdown]
# # T2.L7 — Practice notebook
#
# Заповніть усі блоки `TODO`.

# %%
from pathlib import Path
import sys, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

LESSON_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
SRC_DIR = LESSON_DIR/'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))
from model import *

# %% [markdown]
# ## TODO 1. Research question + hypothesis
#
# Сформулюйте власними словами дослідницьке питання і гіпотезу.

# %%
config = json.loads((LESSON_DIR/'experiment_config.json').read_text(encoding='utf-8'))
data = pd.read_csv(LESSON_DIR/'data'/'synthetic_observations.csv')
data

# %% [markdown]
# ## TODO 2. Calibration
#
# Оцініть `q`, `k`, RMSE та поясніть їх зміст.

# %%
# TODO

# %% [markdown]
# ## TODO 3. Verification
#
# Порівняйте analytical trajectory з `solve_ivp`.

# %%
# TODO

# %% [markdown]
# ## TODO 4. Scenario experiment
#
# Змініть `q` у межах 80–120% і побудуйте таблицю та графік.

# %%
# TODO

# %% [markdown]
# ## TODO 5. Bootstrap uncertainty
#
# Виконайте не менше 300 повторів і наведіть 95% interval.

# %%
# TODO

# %% [markdown]
# ## TODO 6. Scientific interpretation
#
# Напишіть 250–350 слів: result, uncertainty, sensitivity, limitations, allowable claim.

# %% [markdown]
# ## TODO 7. Research transfer
#
# Опишіть аналогічний workflow для власної дисертаційної задачі.
