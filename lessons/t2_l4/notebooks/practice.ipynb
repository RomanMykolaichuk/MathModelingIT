# %% [markdown]
# # T2.L4 Practice
#
# Заповніть TODO. Не обмежуйтеся числовою відповіддю — кожний результат має бути інтерпретований.

# %%
from pathlib import Path
import sys, pandas as pd, matplotlib.pyplot as plt
ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
if (ROOT / "src").exists() is False:
    ROOT = Path("..")
sys.path.insert(0, str(ROOT / "src"))
from model import cpm_schedule, apply_delay, pert_parameters, monte_carlo_project, deadline_probability
tasks = pd.read_csv(ROOT / "data" / "tasks.csv")
pert = pd.read_csv(ROOT / "data" / "pert.csv")

# %% [markdown]
# ## TODO 1 — Baseline CPM
# Розрахуйте schedule, duration і critical path.

# %%
# TODO

# %% [markdown]
# ## TODO 2 — Slack
# Поясніть резерви B, D, F.

# %%
# TODO

# %% [markdown]
# ## TODO 3 — Delay scenarios
# C+3, D+3 і власний сценарій.

# %%
# TODO

# %% [markdown]
# ## TODO 4 — PERT
# Обчисліть mean/variance та визначте найбільш невизначені роботи.

# %%
# TODO

# %% [markdown]
# ## TODO 5 — Monte Carlo
# Не менше 2000 запусків. P50/P80/P90, P(T<=19), critical path frequency.

# %%
# TODO

# %% [markdown]
# ## TODO 6 — Research transfer
# Опишіть мережеву модель для власного дисертаційного дослідження.
