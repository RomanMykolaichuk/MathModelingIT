# %% [markdown]
# # T1.L4 — Класифікація методів математичного моделювання
# Шість постановок → шість методів → verification → interpretation.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / 'src'))
from methods import *

# %% [markdown]
# ## A–B. Один об’єкт: чисельний і символьний метод

# %%
nr = numerical_root()
sr = symbolic_roots()
nr, sr

# %% [markdown]
# ## C. Лінійна оптимізація

# %%
linear_optimization()

# %% [markdown]
# ## D. Monte Carlo

# %%
p = monte_carlo_risk(n_runs=10000, seed=2026)
print(f'Estimated risk: {p:.3f}')

# %% [markdown]
# ## E. Мережевий метод

# %%
critical_path()

# %% [markdown]
# ## F. Багатокритеріальний вибір

# %%
weighted_sum_decision()

# %% [markdown]
# ## Висновок
# Метод визначається структурою задачі та типом потрібного результату, а Python-бібліотека є лише інструментом реалізації.
