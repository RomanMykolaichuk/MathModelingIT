# %% [markdown]
# # T1.L4 — Практична робота
# Для кожного кейсу: визначте метод → обґрунтуйте → реалізуйте → перевірте → інтерпретуйте.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / 'src'))
from methods import *

# %% [markdown]
# ## TODO 1. Numerical vs symbolic
# Отримайте чисельний і символьний корені та поясніть різницю між результатами.

# %%
# TODO

# %% [markdown]
# ## TODO 2. Optimization
# Запустіть LP-модель. Перевірте обидва обмеження вручну.

# %%
# TODO

# %% [markdown]
# ## TODO 3. Monte Carlo
# Порівняйте оцінку ризику для 1 000 і 20 000 запусків з однаковим seed.

# %%
# TODO

# %% [markdown]
# ## TODO 4. Network
# Змініть тривалість одного ребра і перевірте, чи змінився critical path.

# %%
# TODO

# %% [markdown]
# ## TODO 5. MCDA
# Змініть ваги так, щоб reliability стала домінуючим критерієм. Поясніть зміну рейтингу.

# %%
# TODO

# %% [markdown]
# ## Research transfer
# Сформулюйте власну задачу та обґрунтуйте метод, Python-інструмент і verification.
