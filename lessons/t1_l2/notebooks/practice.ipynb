# %% [markdown]
# # T1.L2 — Practice
#
# Виконайте завдання послідовно. Не видаляйте markdown-пояснення; доповнюйте їх власною інтерпретацією.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

LESSON_DIR = Path.cwd()
if LESSON_DIR.name == "notebooks":
    LESSON_DIR = LESSON_DIR.parent
sys.path.insert(0, str(LESSON_DIR / "src"))

from model import *

# %% [markdown]
# ## 1. Класифікація
#
# Для чотирьох моделей із `README.md` заповніть таблицю: детермінована/стохастична, статична/динамічна, дискретна/неперервна, аналітична/імітаційна, тип результату.

# %%
classification = pd.DataFrame([
    # TODO: додайте 4 рядки
], columns=["model", "det_or_stoch", "static_or_dynamic", "discrete_or_continuous", "analytic_or_simulation", "result_type"])
classification

# %% [markdown]
# ## 2. Baseline
#
# Реалізуйте детермінований baseline `S0=120`, `v=6`, `horizon=21`. Контрольний час вичерпання — `20`.

# %%
# TODO
S0 = 120
v = 6
horizon = 21

# %% [markdown]
# ## 3. Дві стохастичні траєкторії
#
# Побудуйте траєкторії для двох різних seed та повторіть один seed для перевірки відтворюваності.

# %%
# TODO
params = ResourceModelParams(120, 6, 1.5, 21)

# %% [markdown]
# ## 4. Monte Carlo
#
# Виконайте 3000 запусків із `seed=2026`. Для baseline probability exhaustion до кінця горизонту має бути близько `0.80`.

# %%
# TODO

# %% [markdown]
# ## 5. Сценарний аналіз
#
# Порівняйте `sigma=0.5`, `sigma=3.0`, `mu=7.0`. Побудуйте таблицю та поясніть, що змінює центр розподілу, а що — його розкид.

# %%
# TODO
scenarios = pd.read_csv(LESSON_DIR / "data" / "scenarios.csv")
scenarios

# %% [markdown]
# ## 6. Verification
#
# Підтвердьте:
# - `T=20`;
# - ручний дискретний шлях `[20,15,8,0]`;
# - однаковий seed дає однакові значення;
# - запас не від'ємний;
# - probability належить `[0,1]`.

# %%
# TODO: ваші assert / sanity checks

# %% [markdown]
# ## 7. Інтерпретація
#
# Напишіть 150–250 слів: чому одна stochastic trajectory не може замінити Monte Carlo distribution і що саме означає отримана probability у межах моделі.

# %% [markdown]
# **Ваш висновок:**
# TODO

# %% [markdown]
# ## 8. Research transfer
#
# Оберіть один процес власного дисертаційного дослідження. Вкажіть:
# 1. змінну стану;
# 2. параметри;
# 3. джерело невизначеності;
# 4. детерміновану версію;
# 5. стохастичну версію;
# 6. показник для Monte Carlo.
#
# **Відповідь:**
# TODO
