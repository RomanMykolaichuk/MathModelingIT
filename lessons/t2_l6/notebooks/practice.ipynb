# %% [markdown]
# # T2.L6 Practice
#
# Заповніть `TODO`. Мета — пройти весь ланцюг **symbolic → numerical → verification → interpretation**.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy as sp

lesson = Path.cwd()
if lesson.name == "notebooks":
    lesson = lesson.parent
sys.path.insert(0, str(lesson / "src"))

from model import *

# %% [markdown]
# ## 1. Побудуйте символи та ODE

# %%
# TODO: отримайте symbolic_model() та виведіть ode, equilibrium, solution
sm = None

# %% [markdown]
# ## 2. Перевірте residual

# %%
# TODO: переконайтеся, що symbolic residual = 0

# %% [markdown]
# ## 3. Baseline

# %%
q = 12.0
k = 0.10
s0 = 20.0

# TODO: обчисліть S*, S(10), integral 0..10 і t(S=80)

# %% [markdown]
# ## 4. Lambdify

# %%
times = np.linspace(0, 30, 121)
# TODO: створіть lambdified function і порівняйте з analytical_solution

# %% [markdown]
# ## 5. SciPy verification

# %%
# TODO: обчисліть solve_ivp trajectory та max absolute error

# %% [markdown]
# ## 6. Sensitivity

# %%
# TODO:
# 1) виберіть щонайменше 5 значень k
# 2) обчисліть equilibrium і S(10)
# 3) побудуйте графік

# %% [markdown]
# ## 7. Інтерпретація
#
# TODO:
#
# 1. Чому \(S^*\) змінюється саме так?
# 2. Що дає символьна похідна, чого не дає одна таблиця?
# 3. Що саме підтверджує збіг SymPy/NumPy/SciPy?
# 4. Чого цей збіг **не** підтверджує?
# 5. Як перенести workflow на власне дослідження?
