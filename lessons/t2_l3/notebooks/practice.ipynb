# %% [markdown]
# # T2.L3 Practice
# Заповніть TODO та сформулюйте дослідницькі висновки.

# %%
from pathlib import Path
import sys, pandas as pd, numpy as np, matplotlib.pyplot as plt
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT/'src'))
from model import *

# %% [markdown]
# ## TODO 1 — baseline

# %%
# TODO: розв'яжіть applied model для R=100
baseline = None
baseline

# %% [markdown]
# ## TODO 2 — verification

# %%
# TODO: перевірте x>=0, y>=0, x+y<=R

# %% [markdown]
# ## TODO 3 — sensitivity

# %%
# TODO: R = 60,80,100,120; створіть DataFrame і графік

# %% [markdown]
# ## TODO 4 — стартові точки

# %%
# TODO: порівняйте (10,10),(80,10),(10,80),(50,50)

# %% [markdown]
# ## TODO 5 — non-convex multi-start

# %%
# TODO: завантажте data/nonconvex_starts.csv і порівняйте локальні оптимуми

# %% [markdown]
# ## TODO 6 — independent grid check

# %%
# TODO: виконайте grid_search_nonconvex(step=0.05) і порівняйте з multi-start

# %% [markdown]
# ## TODO 7 — Research transfer
# Опишіть власну нелінійну модель: змінні, objective, constraints, джерело нелінійності, дані, verification.
