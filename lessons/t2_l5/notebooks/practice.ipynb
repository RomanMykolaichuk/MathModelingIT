# %% [markdown]
# # T2.L5 Practice
# Заповніть TODO.

# %%
from pathlib import Path
import sys, pandas as pd, numpy as np, matplotlib.pyplot as plt
BASE = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(BASE/"src"))
from model import weighted_sum, topsis, one_factor_sensitivity, robustness_analysis
M = pd.read_csv(BASE/"data"/"alternatives.csv").set_index("alternative")
C = pd.read_csv(BASE/"data"/"criteria.csv")
W = C.set_index("criterion")["weight"].astype(float)
T = C.set_index("criterion")["type"].to_dict()

# %% [markdown]
# ## TODO 1
# Перевірте benefit/cost classification та поясніть його предметний зміст.

# %%
# TODO

# %% [markdown]
# ## TODO 2
# Побудуйте WSM і TOPSIS. Порівняйте rankings.

# %%
# TODO

# %% [markdown]
# ## TODO 3
# Змініть вагу одного критерію в діапазоні та знайдіть точки зміни лідера.

# %%
# TODO

# %% [markdown]
# ## TODO 4
# Проведіть robustness analysis щонайменше на 2000 запусках.

# %%
# TODO

# %% [markdown]
# ## TODO 5 — Research transfer
# Створіть власну decision matrix і сформулюйте обмеження висновку.
